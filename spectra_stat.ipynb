# %%
import pandas as pd

# %%
import spectra_preprocessing as sp

# %%
# %matplotlib inline

# %%
path = 'datasets/Raman-SBN-50-Pt-Si/txt/'

# %%
spectra = pd.DataFrame()

# %%
spectra = sp.txt_to_pd(path)

# %%
spectra.head()
# Out:
#    Wavenumber      300      310      320      330      340      350      360  \
# 0     988.543  2453.01  3940.82  4082.07  4499.54  3779.17  3921.99  4435.19
# 1     986.950  2445.16  3964.36  4204.48  4518.37  3699.13  3958.08  4507.38
# 2     985.357  2502.51  3945.96  4261.32  4593.94  3767.09  3930.27  4479.41
# 3     983.763  2493.94  3957.37  4314.99  4534.58  3824.04  3973.05  4586.34
# 4     982.169  2519.88  4056.59  4301.21  4544.26  3832.35  3924.87  4514.46
#
#        370      380  ...      610      620      630      640      650  \
# 0  4421.06  3939.25  ...  2066.93  1878.60  1971.20  1975.90  1721.66
# 1  4504.24  3917.28  ...  2131.28  1902.14  1958.64  1996.31  1796.99
# 2  4504.51  3989.89  ...  2160.47  1921.99  2061.62  1959.64  1771.37
# 3  4490.66  3958.94  ...  2104.95  1913.59  2158.28  2045.35  1792.81
# 4  4454.88  4014.25  ...  2179.61  1894.22  2027.51  2060.44  1789.16
#
#        660      670      680      690      700
# ...

# %%
spectra.describe()
# Out:
#        Wavenumber           300           310           320           330  \
# count  551.000000    551.000000    551.000000    551.000000    551.000000
# mean   532.486052   8129.754846  14336.419129  14977.734319  15485.721180
# std    269.022569   4462.274790   8092.968399   8330.355991   8407.325317
# min     59.025400   2388.370000   3940.820000   4082.070000   4499.540000
# 25%    301.384000   4373.855000   7535.870000   7972.295000   8410.835000
# 50%    536.825000   5918.040000  10460.000000  10988.500000  11595.600000
# 75%    765.816000  12451.900000  22242.150000  22907.200000  23474.050000
# max    988.543000  17747.400000  32182.200000  33419.800000  34218.800000
#
#                 340           350           360           370           380  \
# count    551.000000    551.000000    551.000000    551.000000    551.000000
# mean   12546.658548  12582.761488  13463.329637  12755.645082  10822.143920
# ...

# %%
fig = spectra.plot(x='Wavenumber', y=range(300, 410, 10))
fig.set_xlabel('Wavenumber, $cm^{-1}$')
fig.set_ylabel('Intensity, arb. units')
# Out:
# Text(0, 0.5, 'Intensity, arb. units')
